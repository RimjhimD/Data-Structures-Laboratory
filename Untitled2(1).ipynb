# %%
print('depression!!!')
# Out:
# depression!!!

# %%
intVar = 69
floatVar = 6.9
stringVar = 'bitch'

print(type(intVar))
print(type(floatVar))
print(type(stringVar))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
